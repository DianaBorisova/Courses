# %%
import pandas as pd
import numpy as np
import holoviews as hv
import seaborn as sns
hv.extension('matplotlib')

import matplotlib.pyplot as plt
# Out:
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %% [markdown]
# # Считываем данные

# %% [markdown]
# Датасет лежит по ссылке: https://drive.google.com/file/d/1Cx5CUQkeJHVRBgvdVabTWRG_v1QYCiel/view?usp=sharing

# %%
# !pip install -q gdown
# !gdown https://drive.google.com/uc?id=1Cx5CUQkeJHVRBgvdVabTWRG_v1QYCiel
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Cx5CUQkeJHVRBgvdVabTWRG_v1QYCiel
# To: /content/income_dataset.csv
# 100% 867k/867k [00:00<00:00, 45.3MB/s]

# %%
df = pd.read_csv('income_dataset.csv')

# %%
df.head()
# Out:
#    monthly_income_amt education_level_cd  ... wrst_delqbalance_max  cred_av
# 0                30.0                UGR  ...                 0.00   62.430
# 1                48.0                SCH  ...                 0.00   33.098
# 2                30.0                GRD  ...                 8.86   75.387
# 3                11.0                SCH  ...                 0.00   51.450
# 4                30.0                GRD  ...                 0.00   54.583
#
# [5 rows x 14 columns]

# %%
df = (
    df.assign(low_age = lambda x:np.where(x.age <= 38,x.age,38))
      .assign(high_age = lambda x:np.where(x.age > 38,x.age,38))
)

# %%
df = (df.assign(credit_amt_max = lambda x:x.credit_amt_max.clip(1,np.percentile(x.credit_amt_max, 99)))\
       .assign(credit_amt_max = lambda x:np.log(x.credit_amt_max)))

# %% [markdown]
# # Краткое описание признаков
# * monthly_income_amt - месячный доход(в тысячах)
# * education_level_cd - уровень образования (категориальная переменная)
# * gender_cd - пол (M - мужчина, F - женщина) (категориальная переменная)
# * age - возраст
# * job_position_cd - позиция (категориальная переменная)
# * marital_status_cd - семейный статус (категориальная переменная)
# * car_own_flg - флаг наличия машины
# * work_exp_cd - стаж на последней работе (категориальная переменная)
# * accnt_cnt - количество счетов
# * credit_amt_max - максимальная сумма выданного кредита (в тысячах)
# * credit_card_sum - сумма кредитов по открытым револьверным кредитам (в тысячах)
# * accnt_open_due_cnt - количество открытых просроченных счетов
# * wrst_delqbalance_max - сумма максимальной исторической просрочки (в тысячах)
# * cred_av - средняя сумма кредита (в тысячах)

# %% [markdown]
# #Задание
#
# Усилить модель линейной регрессии, построенную на лекции, за счет добавления новых переменных.
#
# Целевая переменная - месячный доход monthly_income_amt.
#
#
# 1. Выполнить проверку переменных (минимум 5 шт),  преобразовать их при необходимости - 3 балла
#
# 2. Построить на отобранных данных модель линейной регрессии 1 балл
#
# 3. Оценить качество модели, проверить ее на тестовой выборке - 1 балл

# %% [markdown]
# #Проверка на линейность

# %%
from sklearn.linear_model import LinearRegression
def simple_reg(predictor, target):
    '''вспомогательная функция, отрисовка прямой для простой регресии'''
    check = LinearRegression()
    check.fit(predictor.reshape(-1,1),target)
    return hv.Curve((np.array([i for i in np.linspace(min(predictor),max(predictor),100)]),
                     check.coef_*np.array([i for i in np.linspace(min(predictor),
                                                                  max(predictor),100)]) + check.intercept_))

# %%
def make_bucket(df,feature, n =  100):
    '''функция, бьющая на бакеты(по умолчанию 100 точек)'''
    return df.assign(bucket = np.ceil(df[feature].rank(pct = True) * n))

# %%
# сумма кредитов по открытым револьверным кредитам (в тысячах)
# %%output size=200
df.pipe(make_bucket,'credit_card_sum')\
  .groupby(by = ['bucket']).mean()\
  .pipe(lambda x:hv.Scatter(zip(np.array(x['credit_card_sum']), np.array(x['monthly_income_amt'])),
                            kdims = ['credit_card_sum'],vdims=['monthly_income_amt'],
                            label = 'Проверка линейности зависимости monthly_income_amt от credit_card_sum')
         *simple_reg(np.array(df.credit_card_sum),np.array(df.monthly_income_amt)))
# Out:
# :Overlay
#    .Scatter.Проверка_линейности_зависимости_monthly_income_amt_от_credit_card_sum :Scatter   [credit_card_sum]   (monthly_income_amt)
#    .Curve.I                                                                       :Curve   [x]   (y)

# %%
# сумма максимальной исторической просрочки (в тысячах)
# %%output size=200
df.pipe(make_bucket,'wrst_delqbalance_max')\
  .groupby(by = ['bucket']).mean()\
  .pipe(lambda x:hv.Scatter(zip(np.array(x['wrst_delqbalance_max']), np.array(x['monthly_income_amt'])),
                            kdims = ['wrst_delqbalance_max'],vdims=['monthly_income_amt'],
                            label = 'Проверка линейности зависимости monthly_income_amt от wrst_delqbalance_max')
         *simple_reg(np.array(df.wrst_delqbalance_max),np.array(df.monthly_income_amt)))
# Out:
# :Overlay
#    .Scatter.Проверка_линейности_зависимости_monthly_income_amt_от_wrst_delqbalance_max :Scatter   [wrst_delqbalance_max]   (monthly_income_amt)
#    .Curve.I                                                                            :Curve   [x]   (y)

# %%
# возьмем логарифм, предварительно отсекая все не попавшее в 99% квантиль
df = (df.assign(wrst_delqbalance_max = lambda x:x.wrst_delqbalance_max.clip(1,np.percentile(x.wrst_delqbalance_max, 99)))\
       .assign(wrst_delqbalance_max = lambda x:np.log(x.wrst_delqbalance_max)))

# %%
# %%output size=200
# df.pipe(make_bucket,'wrst_delqbalance_max')\
#   .groupby(by = ['bucket']).mean()\
#   .pipe(lambda x:hv.Scatter(zip(np.array(x['wrst_delqbalance_max']), np.array(x['monthly_income_amt'])),
#                             kdims = ['wrst_delqbalance_max'],vdims=['monthly_income_amt'],
#                             label = 'Проверка линейности зависимости monthly_income_amt от wrst_delqbalance_max')
#          *simple_reg(np.array(df.wrst_delqbalance_max),np.array(df.monthly_income_amt)))
# Out:
# :Overlay
#    .Scatter.Проверка_линейности_зависимости_monthly_income_amt_от_wrst_delqbalance_max :Scatter   [wrst_delqbalance_max]   (monthly_income_amt)
#    .Curve.I                                                                            :Curve   [x]   (y)

# %%
# средняя сумма кредита (в тысячах)
# %%output size=200
df.pipe(make_bucket,'cred_av')\
  .groupby(by = ['bucket']).mean()\
  .pipe(lambda x:hv.Scatter(zip(np.array(x['cred_av']), np.array(x['monthly_income_amt'])),
                            kdims = ['cred_av'],vdims=['monthly_income_amt'],
                            label = 'Проверка линейности зависимости monthly_income_amt от cred_av')
         *simple_reg(np.array(df.cred_av),np.array(df.monthly_income_amt)))
# Out:
# :Overlay
#    .Scatter.Проверка_линейности_зависимости_monthly_income_amt_от_cred_av :Scatter   [cred_av]   (monthly_income_amt)
#    .Curve.I                                                               :Curve   [x]   (y)

# %%
df = (df.assign(cred_av = lambda x:x.cred_av.clip(1,np.percentile(x.cred_av, 99)))\
       .assign(cred_av = lambda x:np.log(x.cred_av)))

# %%
# %%output size=200
# df.pipe(make_bucket,'cred_av')\
#   .groupby(by = ['bucket']).mean()\
#   .pipe(lambda x:hv.Scatter(zip(np.array(x['cred_av']), np.array(x['monthly_income_amt'])),
#                             kdims = ['cred_av'],vdims=['monthly_income_amt'],
#                             label = 'Проверка линейности зависимости monthly_income_amt от cred_av')
#          *simple_reg(np.array(df.cred_av),np.array(df.monthly_income_amt)))
# Out:
# :Overlay
#    .Scatter.Проверка_линейности_зависимости_monthly_income_amt_от_cred_av :Scatter   [cred_av]   (monthly_income_amt)
#    .Curve.I                                                               :Curve   [x]   (y)

# %% [markdown]
# # Посмотрим на категориальные переменные

# %%
# позиция
sns.boxplot(x='job_position_cd',y='monthly_income_amt',data=df);

# %%
# семейный статус
sns.boxplot(x='marital_status_cd',y='monthly_income_amt',data=df);

# %%
# флаг наличия машины
sns.boxplot(x='car_own_flg',y='monthly_income_amt',data=df);

# %%
# стаж на последней работе
sns.boxplot(x='work_exp_cd',y='monthly_income_amt',data=df);

# %%
# количество открытых просроченных счетов
sns.boxplot(x='accnt_open_due_cnt',y='monthly_income_amt',data=df);

# %% [markdown]
# # Проверим гомоскедастичность

# %%
def get_residuals(Y,Pred):
    '''Подсчет невязки Y - истинное значение таргета, Pred - предсказанное'''
    return Y - Pred

# %%
def check_homoscedacity(predictor,target,f_name):
    simple_model = LinearRegression()
    simple_model.fit(predictor.reshape(-1,1),target)
    predicts = simple_model.predict(predictor.reshape(-1,1))
    return (hv.Scatter(zip(predicts,get_residuals(target,predicts)),\
              kdims = ['Y_estimate'],vdims=['Residual'], 
                       label = f'Проверка гомоскедастичности признака {f_name}')
            .opts(plot=dict(width=1200,height=900))  
)

# %%
# %%output size = 200
# hv.Layout([df.pipe(make_bucket,f,400)\
#              .groupby(by = ['bucket']).mean()\
#              .pipe(lambda x:check_homoscedacity(np.array(x[f]),np.array(x.monthly_income_amt),f))
#            for f in ['credit_card_sum','wrst_delqbalance_max','cred_av']]).cols(2)
# Out:
# :Layout
#    .Scatter.Проверка_гомоскедастичности_признака_credit_card_sum      :Scatter   [Y_estimate]   (Residual)
#    .Scatter.Проверка_гомоскедастичности_признака_wrst_delqbalance_max :Scatter   [Y_estimate]   (Residual)
#    .Scatter.Проверка_гомоскедастичности_признака_cred_av              :Scatter   [Y_estimate]   (Residual)

# %% [markdown]
# Заметны проблемы с гомоскедастичностью признака cred_av

# %% [markdown]
# # Проверка на нормальность

# %%
numeric_show = ['credit_card_sum','wrst_delqbalance_max','cred_av']

# %%
model = LinearRegression()
model.fit(np.array(df[numeric_show]),df['monthly_income_amt'])
resids = get_residuals(df['monthly_income_amt'],(model.predict(df[numeric_show])))
plt.hist(resids, bins='auto')[2]
plt.xlabel('отклонение')
plt.ylabel('количество наблюдений')
plt.title('Распределение остатков')
plt.axis([-100, 100, 0, 600])
plt.grid(True)
plt.show()

# %% [markdown]
# # Проверим мультиколлинеарность

# %%
features = ['credit_card_sum','wrst_delqbalance_max','cred_av']

# %%
from scipy.stats.stats import pearsonr   
import seaborn as sns

pcorr = pd.DataFrame 
pcorr = []
for f1 in features:
    for f2 in features:
        pcorr.append((f1,f2,pearsonr(df[f1],df[f2])))
        
cor = df.loc[:,features].corr(method='pearson')
cm=plt.cm.viridis
sns.heatmap(cor,cmap=cm,linewidths=0.1,linecolor='white',annot=True)
plt.show()

# %% [markdown]
# # Построим модель линейной регрессии из statsmodels и оценим ее качество

# %%
import statsmodels.api as sm
import statsmodels.formula.api as ols
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
model = ols.ols(formula = 'monthly_income_amt ~ credit_card_sum + wrst_delqbalance_max + cred_av + job_position_cd + marital_status_cd \
                                                    + car_own_flg + work_exp_cd + accnt_open_due_cnt + education_level_cd + gender_cd + high_age + low_age + credit_amt_max + accnt_cnt' , data = df)
res = model.fit()

# %%
print('r2 = ' + str(round(res.rsquared,3)))
# Out:
# r2 = 0.238

# %% [markdown]
# # Обучим модель с отбором признаков

# %%
import statsmodels.formula.api as smf

def forward_selected(data, response):
    """Linear model designed by forward selection.

    Parameters:
    -----------
    data : pandas DataFrame with all possible predictors and response

    response: string, name of response column in data

    Returns:
    --------
    model: an "optimal" fitted statsmodels linear model
           with an intercept
           selected by forward selection
           evaluated by adjusted R-squared
    """
    remaining = set(data.columns)
    remaining.remove(response)
    selected = []
    current_score, best_new_score = 0.0, 0.0
    while remaining and current_score == best_new_score:
        scores_with_candidates = []
        for candidate in remaining:
            formula = "{} ~ {} + 1".format(response,
                                           ' + '.join(selected + [candidate]))
            score = smf.ols(formula, data).fit().rsquared_adj
            scores_with_candidates.append((score, candidate))
        scores_with_candidates.sort()
        best_new_score, best_candidate = scores_with_candidates.pop()
        if current_score < best_new_score:
            remaining.remove(best_candidate)
            selected.append(best_candidate)
            current_score = best_new_score
    formula = "{} ~ {} + 1".format(response,
                                   ' + '.join(selected))
    model = smf.ols(formula, data).fit()
    return model

# %%
feature = ['credit_card_sum', 'wrst_delqbalance_max', 'cred_av', 'job_position_cd', 'marital_status_cd' \
                              , 'car_own_flg', 'work_exp_cd', 'accnt_open_due_cnt', 'accnt_cnt', 'credit_amt_max', 'low_age', 'high_age', 'gender_cd', 'education_level_cd']

# %%
test_model = forward_selected(df[feature + ['monthly_income_amt']],'monthly_income_amt')

# %% [markdown]
# # Оценим качество модели на тестовой выборке

# %%
from sklearn.metrics import r2_score

# %%
test = df[10000:]
df = df[:10000]

# %%
print('r_square = ' + str(round(
         r2_score(test.monthly_income_amt,
                  test_model.predict(test.loc[:, test.columns != 'monthly_income_amt']))
     ,4)))
# Out:
# r_square = 0.2388
